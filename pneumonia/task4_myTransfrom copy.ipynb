# %%
from functions import *
from torchvision.transforms import InterpolationMode


# --- Configuration ---
class Config:
    saved_dir = 'saved'
    data_dir = "./pnev"
    backbone = "resnet18"
    version = 'pneumonia_task4'
    projection_dim = 128
    batch_size = 512
    simclr_epochs = 100
    learning_rate = 0.6
    weight_decay = 1e-6
    temperature = 0.5
    finetune_epochs = 100
    log_interval = 1

args = Config()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

from torchvision.models import resnet18
import torch
from torch.optim import SGD
from torch.optim.lr_scheduler import LambdaLR, CosineAnnealingLR
from torchvision.models import resnet18
from torchvision import transforms
from torch.utils.data import DataLoader

train_transform = transforms.Compose([
    transforms.RandomResizedCrop(
        size=(224, 224),
        scale=(0.75, 1.0),
        ratio=(0.75, 1.0),
        interpolation=InterpolationMode.BICUBIC,
        antialias=True
    ),
    transforms.RandomApply(
        [transforms.ColorJitter(
            brightness=(0.9, 1.1),
            contrast=(0.9, 1.1),
            saturation=(0.9, 1.1),
            hue=(-0.1, 0.1)
        )],
        p=0.7
    ),
    transforms.RandomHorizontalFlip(p=0.5),

    transforms.ToTensor(),
])

# %%
from medmnist import ChestMNIST, PneumoniaMNIST

# pneumoniamnist = GenericPairDataset(split='train', download=True, as_rgb=False, size=224)
pneumoniamnist = PneumoniaMNIST(split='train', download=True, as_rgb=False, size=224)
pneum_pair = GenericPairDataset(pneumoniamnist, transform=train_transform)
train_loader = DataLoader(pneum_pair, batch_size=args.batch_size, shuffle=True)


visualize(train_transform, pneumoniamnist, num_examples=5)
# Out:
# Using downloaded and verified file: C:\Users\sever\.medmnist\pneumoniamnist_224.npz

# %%
base_encoder = resnet18
model = SimCLR(base_encoder, projection_dim=args.projection_dim).to(device)

optimizer = SGD(model.parameters(), lr=args.learning_rate, momentum=0.9, weight_decay=args.weight_decay)
scheduler = LambdaLR(optimizer, lr_lambda=lambda step: get_lr(step, args.simclr_epochs * len(train_loader), args.learning_rate, 1e-4))

train_loss_simclr = train_simclr(model, train_loader, optimizer, scheduler, device, args.simclr_epochs)
torch.save(model.state_dict(), f"./{args.saved_dir}/{args.version}.pt")
# Out:
# c:\Users\sever\OneDrive\Рабочий стол\Homework2\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\sever\OneDrive\Рабочий стол\Homework2\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# 100%|██████████| 10/10 [00:15<00:00,  1.50s/it]
# INFO:functions:Epoch 1, Avg Loss: 6.4670
# 100%|██████████| 10/10 [00:14<00:00,  1.45s/it]
# INFO:functions:Epoch 2, Avg Loss: 6.1855
# 100%|██████████| 10/10 [00:14<00:00,  1.46s/it]
# INFO:functions:Epoch 3, Avg Loss: 6.0418
# 100%|██████████| 10/10 [00:14<00:00,  1.45s/it]
# INFO:functions:Epoch 4, Avg Loss: 5.9127
# 100%|██████████| 10/10 [00:14<00:00,  1.46s/it]
# INFO:functions:Epoch 5, Avg Loss: 5.7364
# 100%|██████████| 10/10 [00:14<00:00,  1.43s/it]
# INFO:functions:Epoch 6, Avg Loss: 5.6255
# 100%|██████████| 10/10 [00:09<00:00,  1.03it/s]
# INFO:functions:Epoch 7, Avg Loss: 5.5955
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 8, Avg Loss: 5.5865
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 9, Avg Loss: 5.5721
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# INFO:functions:Epoch 10, Avg Loss: 5.5615
# 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]
# INFO:functions:Epoch 11, Avg Loss: 5.5587
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 12, Avg Loss: 5.5518
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 13, Avg Loss: 5.5483
# 100%|██████████| 10/10 [00:08<00:00,  1.15it/s]
# INFO:functions:Epoch 14, Avg Loss: 5.5468
# 100%|██████████| 10/10 [00:08<00:00,  1.15it/s]
# INFO:functions:Epoch 15, Avg Loss: 5.5366
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 16, Avg Loss: 5.5153
# 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]
# INFO:functions:Epoch 17, Avg Loss: 5.4856
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 18, Avg Loss: 5.4730
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 19, Avg Loss: 5.4375
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 20, Avg Loss: 5.4060
# 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]
# INFO:functions:Epoch 21, Avg Loss: 5.3983
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 22, Avg Loss: 5.3606
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 23, Avg Loss: 5.3483
# 100%|██████████| 10/10 [00:08<00:00,  1.15it/s]
# INFO:functions:Epoch 24, Avg Loss: 5.3327
# 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]
# INFO:functions:Epoch 25, Avg Loss: 5.3195
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 26, Avg Loss: 5.3075
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 27, Avg Loss: 5.2907
# 100%|██████████| 10/10 [00:08<00:00,  1.21it/s]
# INFO:functions:Epoch 28, Avg Loss: 5.2836
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# INFO:functions:Epoch 29, Avg Loss: 5.2757
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# INFO:functions:Epoch 30, Avg Loss: 5.2688
# 100%|██████████| 10/10 [00:08<00:00,  1.21it/s]
# INFO:functions:Epoch 31, Avg Loss: 5.2533
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 32, Avg Loss: 5.2407
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 33, Avg Loss: 5.2371
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# INFO:functions:Epoch 34, Avg Loss: 5.2240
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 35, Avg Loss: 5.2187
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 36, Avg Loss: 5.2127
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 37, Avg Loss: 5.2020
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# INFO:functions:Epoch 38, Avg Loss: 5.1943
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# INFO:functions:Epoch 39, Avg Loss: 5.1880
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 40, Avg Loss: 5.1844
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# INFO:functions:Epoch 41, Avg Loss: 5.1782
# 100%|██████████| 10/10 [00:08<00:00,  1.21it/s]
# INFO:functions:Epoch 42, Avg Loss: 5.1712
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 43, Avg Loss: 5.1606
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 44, Avg Loss: 5.1541
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# INFO:functions:Epoch 45, Avg Loss: 5.1528
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 46, Avg Loss: 5.1490
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# INFO:functions:Epoch 47, Avg Loss: 5.1436
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# INFO:functions:Epoch 48, Avg Loss: 5.1428
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 49, Avg Loss: 5.1385
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 50, Avg Loss: 5.1361
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# INFO:functions:Epoch 51, Avg Loss: 5.1343
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 52, Avg Loss: 5.1300
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 53, Avg Loss: 5.1300
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# INFO:functions:Epoch 54, Avg Loss: 5.1280
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 55, Avg Loss: 5.1270
# 100%|██████████| 10/10 [00:08<00:00,  1.21it/s]
# INFO:functions:Epoch 56, Avg Loss: 5.1218
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 57, Avg Loss: 5.1178
# 100%|██████████| 10/10 [00:08<00:00,  1.21it/s]
# INFO:functions:Epoch 58, Avg Loss: 5.1134
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# INFO:functions:Epoch 59, Avg Loss: 5.1102
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# INFO:functions:Epoch 60, Avg Loss: 5.1104
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 61, Avg Loss: 5.1077
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# INFO:functions:Epoch 62, Avg Loss: 5.1054
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 63, Avg Loss: 5.1046
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# INFO:functions:Epoch 64, Avg Loss: 5.1015
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 65, Avg Loss: 5.0984
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 66, Avg Loss: 5.1000
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 67, Avg Loss: 5.0966
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 68, Avg Loss: 5.0939
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 69, Avg Loss: 5.0930
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# INFO:functions:Epoch 70, Avg Loss: 5.0921
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 71, Avg Loss: 5.0907
# 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]
# INFO:functions:Epoch 72, Avg Loss: 5.0915
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# INFO:functions:Epoch 73, Avg Loss: 5.0905
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 74, Avg Loss: 5.0905
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 75, Avg Loss: 5.0897
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 76, Avg Loss: 5.0874
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 77, Avg Loss: 5.0872
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 78, Avg Loss: 5.0869
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 79, Avg Loss: 5.0855
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# INFO:functions:Epoch 80, Avg Loss: 5.0863
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 81, Avg Loss: 5.0862
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 82, Avg Loss: 5.0856
# 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]
# INFO:functions:Epoch 83, Avg Loss: 5.0863
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 84, Avg Loss: 5.0843
# 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]
# INFO:functions:Epoch 85, Avg Loss: 5.0827
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 86, Avg Loss: 5.0825
# 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]
# INFO:functions:Epoch 87, Avg Loss: 5.0827
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 88, Avg Loss: 5.0815
# 100%|██████████| 10/10 [00:08<00:00,  1.18it/s]
# INFO:functions:Epoch 89, Avg Loss: 5.0825
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 90, Avg Loss: 5.0811
# 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]
# INFO:functions:Epoch 91, Avg Loss: 5.0812
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# INFO:functions:Epoch 92, Avg Loss: 5.0821
# 100%|██████████| 10/10 [00:08<00:00,  1.13it/s]
# INFO:functions:Epoch 93, Avg Loss: 5.0809
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 94, Avg Loss: 5.0820
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 95, Avg Loss: 5.0802
# 100%|██████████| 10/10 [00:08<00:00,  1.21it/s]
# INFO:functions:Epoch 96, Avg Loss: 5.0812
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# INFO:functions:Epoch 97, Avg Loss: 5.0804
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# INFO:functions:Epoch 98, Avg Loss: 5.0805
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# INFO:functions:Epoch 99, Avg Loss: 5.0805
# 100%|██████████| 10/10 [00:08<00:00,  1.15it/s]
# INFO:functions:Epoch 100, Avg Loss: 5.0796

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(range(1, args.simclr_epochs + 1), train_loss_simclr, label="SimCLR Loss", marker='o')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("SimCLR Pretraining Loss")
plt.legend()
plt.grid(True)

plt.savefig(f'./{args.saved_dir}/pretrain_{args.version}.jpg') 

plt.show()

# %%
# Linear Probe
from medmnist import PneumoniaMNIST

test_transform = transforms.Compose([
    transforms.ToTensor(),
])

train_set_single = PneumoniaMNIST(split='train', download=True, as_rgb=False, transform=train_transform)
test_set_single = PneumoniaMNIST(split='test', download=True, as_rgb=False, transform=test_transform)
train_loader_single = DataLoader(train_set_single, batch_size=args.batch_size, shuffle=True)
test_loader_single = DataLoader(test_set_single, batch_size=args.batch_size, shuffle=False)
# Out:
# Using downloaded and verified file: C:\Users\sever\.medmnist\pneumoniamnist.npz
# Using downloaded and verified file: C:\Users\sever\.medmnist\pneumoniamnist.npz

# %%
for param in model.enc.parameters():
    param.requires_grad = False
    
lin_model = LinModel(model.enc, model.feature_dim, n_classes=2).to(device)

optimizer = torch.optim.SGD(
    lin_model.parameters(),
    lr=0.2, 
    momentum=0.9,
    weight_decay=0.,
    nesterov=True
)

scheduler = LambdaLR(
    optimizer,
    lr_lambda=lambda step: get_lr(
        step,
        args.finetune_epochs * len(train_loader_single),
        args.learning_rate,
        1e-4
    )
)

# --- Обучение ---
results = train_linear_probe(
    lin_model,
    train_loader_single,
    test_loader_single,
    optimizer,
    scheduler,
    device,
    args.finetune_epochs,
    [0.5, 0.5]
)


train_losses, test_losses, train_f1_scores, test_f1_scores, train_recalls, test_recalls, train_precisions, test_precisions = results
# Out:
# Epoch 1/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.91it/s]
# Epoch 1/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 37.66it/s]
# INFO:functions:Epoch 1/100: Train F1=0.8853, Test F1=0.7692, Train Recall=0.8795, Test Recall=1.0000
# Epoch 2/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.72it/s]
# Epoch 2/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 44.44it/s]
# INFO:functions:Epoch 2/100: Train F1=0.9517, Test F1=0.7692, Train Recall=0.9559, Test Recall=1.0000
# Epoch 3/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.84it/s]
# Epoch 3/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 64.28it/s]
# INFO:functions:Epoch 3/100: Train F1=0.9519, Test F1=0.7692, Train Recall=0.9522, Test Recall=1.0000
# Epoch 4/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.80it/s]
# Epoch 4/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 76.92it/s]
# INFO:functions:Epoch 4/100: Train F1=0.9510, Test F1=0.7692, Train Recall=0.9502, Test Recall=1.0000
# Epoch 5/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.70it/s]
# Epoch 5/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# INFO:functions:Epoch 5/100: Train F1=0.9508, Test F1=0.7692, Train Recall=0.9568, Test Recall=1.0000
# Epoch 6/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.68it/s]
# Epoch 6/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 57.14it/s]
# INFO:functions:Epoch 6/100: Train F1=0.9033, Test F1=0.7692, Train Recall=0.8958, Test Recall=1.0000
# Epoch 7/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.94it/s]
# Epoch 7/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 62.50it/s]
# INFO:functions:Epoch 7/100: Train F1=0.9570, Test F1=0.7692, Train Recall=0.9611, Test Recall=1.0000
# Epoch 8/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.64it/s]
# Epoch 8/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 71.43it/s]
# INFO:functions:Epoch 8/100: Train F1=0.9525, Test F1=0.7692, Train Recall=0.9505, Test Recall=1.0000
# Epoch 9/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.94it/s]
# Epoch 9/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 54.05it/s]
# INFO:functions:Epoch 9/100: Train F1=0.9611, Test F1=0.7692, Train Recall=0.9594, Test Recall=1.0000
# Epoch 10/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.61it/s]
# Epoch 10/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# INFO:functions:Epoch 10/100: Train F1=0.9532, Test F1=0.7692, Train Recall=0.9565, Test Recall=1.0000
# Epoch 11/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.88it/s]
# Epoch 11/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 33.33it/s]
# INFO:functions:Epoch 11/100: Train F1=0.9518, Test F1=0.7692, Train Recall=0.9531, Test Recall=1.0000
# Epoch 12/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.74it/s]
# Epoch 12/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 62.50it/s]
# INFO:functions:Epoch 12/100: Train F1=0.9364, Test F1=0.7692, Train Recall=0.9405, Test Recall=1.0000
# Epoch 13/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.82it/s]
# Epoch 13/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 64.52it/s]
# INFO:functions:Epoch 13/100: Train F1=0.9449, Test F1=0.7692, Train Recall=0.9619, Test Recall=1.0000
# Epoch 14/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.61it/s]
# Epoch 14/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 57.14it/s]
# INFO:functions:Epoch 14/100: Train F1=0.9560, Test F1=0.7692, Train Recall=0.9539, Test Recall=1.0000
# Epoch 15/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.95it/s]
# Epoch 15/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 52.63it/s]
# INFO:functions:Epoch 15/100: Train F1=0.9574, Test F1=0.7692, Train Recall=0.9576, Test Recall=1.0000
# Epoch 16/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.80it/s]
# Epoch 16/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 62.50it/s]
# INFO:functions:Epoch 16/100: Train F1=0.9623, Test F1=0.7692, Train Recall=0.9631, Test Recall=1.0000
# Epoch 17/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.80it/s]
# Epoch 17/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 76.93it/s]
# INFO:functions:Epoch 17/100: Train F1=0.9595, Test F1=0.7692, Train Recall=0.9588, Test Recall=1.0000
# Epoch 18/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.91it/s]
# Epoch 18/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 60.09it/s]
# INFO:functions:Epoch 18/100: Train F1=0.9646, Test F1=0.7692, Train Recall=0.9628, Test Recall=1.0000
# Epoch 19/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.62it/s]
# Epoch 19/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 68.97it/s]
# INFO:functions:Epoch 19/100: Train F1=0.9172, Test F1=0.7692, Train Recall=0.9179, Test Recall=1.0000
# Epoch 20/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.96it/s]
# Epoch 20/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 52.63it/s]
# INFO:functions:Epoch 20/100: Train F1=0.9621, Test F1=0.7692, Train Recall=0.9631, Test Recall=1.0000
# Epoch 21/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.76it/s]
# Epoch 21/100 - Testing: 100%|██████████| 2/2 [00:00<00:00,  6.28it/s]
# INFO:functions:Epoch 21/100: Train F1=0.9646, Test F1=0.7692, Train Recall=0.9639, Test Recall=1.0000
# Epoch 22/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.91it/s]
# Epoch 22/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 55.56it/s]
# INFO:functions:Epoch 22/100: Train F1=0.9553, Test F1=0.7692, Train Recall=0.9568, Test Recall=1.0000
# Epoch 23/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.71it/s]
# Epoch 23/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 60.61it/s]
# INFO:functions:Epoch 23/100: Train F1=0.9678, Test F1=0.7692, Train Recall=0.9725, Test Recall=1.0000
# Epoch 24/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.69it/s]
# Epoch 24/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 76.93it/s]
# INFO:functions:Epoch 24/100: Train F1=0.9672, Test F1=0.7692, Train Recall=0.9665, Test Recall=1.0000
# Epoch 25/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.97it/s]
# Epoch 25/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 55.56it/s]
# INFO:functions:Epoch 25/100: Train F1=0.9445, Test F1=0.7692, Train Recall=0.9399, Test Recall=1.0000
# Epoch 26/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.65it/s]
# Epoch 26/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 64.52it/s]
# INFO:functions:Epoch 26/100: Train F1=0.9671, Test F1=0.7692, Train Recall=0.9685, Test Recall=1.0000
# Epoch 27/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.78it/s]
# Epoch 27/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 66.66it/s]
# INFO:functions:Epoch 27/100: Train F1=0.9154, Test F1=0.7692, Train Recall=0.9179, Test Recall=1.0000
# Epoch 28/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.97it/s]
# Epoch 28/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 58.82it/s]
# INFO:functions:Epoch 28/100: Train F1=0.9641, Test F1=0.7692, Train Recall=0.9657, Test Recall=1.0000
# Epoch 29/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.60it/s]
# Epoch 29/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 64.52it/s]
# INFO:functions:Epoch 29/100: Train F1=0.9643, Test F1=0.7692, Train Recall=0.9631, Test Recall=1.0000
# Epoch 30/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.92it/s]
# Epoch 30/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 56.74it/s]
# INFO:functions:Epoch 30/100: Train F1=0.9635, Test F1=0.7692, Train Recall=0.9605, Test Recall=1.0000
# Epoch 31/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.68it/s]
# Epoch 31/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# INFO:functions:Epoch 31/100: Train F1=0.9678, Test F1=0.7692, Train Recall=0.9708, Test Recall=1.0000
# Epoch 32/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.93it/s]
# Epoch 32/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 54.05it/s]
# INFO:functions:Epoch 32/100: Train F1=0.9646, Test F1=0.7692, Train Recall=0.9619, Test Recall=1.0000
# Epoch 33/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.77it/s]
# Epoch 33/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.08it/s]
# INFO:functions:Epoch 33/100: Train F1=0.9638, Test F1=0.7692, Train Recall=0.9668, Test Recall=1.0000
# Epoch 34/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.68it/s]
# Epoch 34/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 80.00it/s]
# INFO:functions:Epoch 34/100: Train F1=0.9667, Test F1=0.7692, Train Recall=0.9682, Test Recall=1.0000
# Epoch 35/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  3.00it/s]
# Epoch 35/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 58.82it/s]
# INFO:functions:Epoch 35/100: Train F1=0.9514, Test F1=0.7692, Train Recall=0.9473, Test Recall=1.0000
# Epoch 36/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.76it/s]
# Epoch 36/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# INFO:functions:Epoch 36/100: Train F1=0.9669, Test F1=0.7692, Train Recall=0.9665, Test Recall=1.0000
# Epoch 37/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.90it/s]
# Epoch 37/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 52.63it/s]
# INFO:functions:Epoch 37/100: Train F1=0.9692, Test F1=0.7692, Train Recall=0.9679, Test Recall=1.0000
# Epoch 38/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.85it/s]
# Epoch 38/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 60.61it/s]
# INFO:functions:Epoch 38/100: Train F1=0.9652, Test F1=0.7692, Train Recall=0.9648, Test Recall=1.0000
# Epoch 39/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.74it/s]
# Epoch 39/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 71.43it/s]
# INFO:functions:Epoch 39/100: Train F1=0.9677, Test F1=0.7692, Train Recall=0.9702, Test Recall=1.0000
# Epoch 40/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.88it/s]
# Epoch 40/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 60.61it/s]
# INFO:functions:Epoch 40/100: Train F1=0.9658, Test F1=0.7692, Train Recall=0.9657, Test Recall=1.0000
# Epoch 41/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.86it/s]
# Epoch 41/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 60.61it/s]
# INFO:functions:Epoch 41/100: Train F1=0.9626, Test F1=0.7692, Train Recall=0.9622, Test Recall=1.0000
# Epoch 42/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.75it/s]
# Epoch 42/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 58.82it/s]
# INFO:functions:Epoch 42/100: Train F1=0.9709, Test F1=0.7692, Train Recall=0.9691, Test Recall=1.0000
# Epoch 43/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.66it/s]
# Epoch 43/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 55.56it/s]
# INFO:functions:Epoch 43/100: Train F1=0.9623, Test F1=0.7692, Train Recall=0.9648, Test Recall=1.0000
# Epoch 44/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.69it/s]
# Epoch 44/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# INFO:functions:Epoch 44/100: Train F1=0.9686, Test F1=0.7692, Train Recall=0.9702, Test Recall=1.0000
# Epoch 45/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.90it/s]
# Epoch 45/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 58.82it/s]
# INFO:functions:Epoch 45/100: Train F1=0.9737, Test F1=0.7692, Train Recall=0.9737, Test Recall=1.0000
# Epoch 46/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.73it/s]
# Epoch 46/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 61.58it/s]
# INFO:functions:Epoch 46/100: Train F1=0.9726, Test F1=0.7692, Train Recall=0.9714, Test Recall=1.0000
# Epoch 47/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.92it/s]
# Epoch 47/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 57.14it/s]
# INFO:functions:Epoch 47/100: Train F1=0.9656, Test F1=0.7692, Train Recall=0.9642, Test Recall=1.0000
# Epoch 48/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.82it/s]
# Epoch 48/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 68.97it/s]
# INFO:functions:Epoch 48/100: Train F1=0.9704, Test F1=0.7692, Train Recall=0.9705, Test Recall=1.0000
# Epoch 49/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.94it/s]
# Epoch 49/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 57.14it/s]
# INFO:functions:Epoch 49/100: Train F1=0.9728, Test F1=0.7692, Train Recall=0.9734, Test Recall=1.0000
# Epoch 50/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.94it/s]
# Epoch 50/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 66.67it/s]
# INFO:functions:Epoch 50/100: Train F1=0.9682, Test F1=0.7692, Train Recall=0.9705, Test Recall=1.0000
# Epoch 51/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.86it/s]
# Epoch 51/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 52.63it/s]
# INFO:functions:Epoch 51/100: Train F1=0.9643, Test F1=0.7692, Train Recall=0.9634, Test Recall=1.0000
# Epoch 52/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.74it/s]
# Epoch 52/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 71.43it/s]
# INFO:functions:Epoch 52/100: Train F1=0.9742, Test F1=0.7692, Train Recall=0.9742, Test Recall=1.0000
# Epoch 53/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.93it/s]
# Epoch 53/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 40.00it/s]
# INFO:functions:Epoch 53/100: Train F1=0.9721, Test F1=0.7692, Train Recall=0.9717, Test Recall=1.0000
# Epoch 54/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.69it/s]
# Epoch 54/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# INFO:functions:Epoch 54/100: Train F1=0.9691, Test F1=0.7692, Train Recall=0.9699, Test Recall=1.0000
# Epoch 55/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.87it/s]
# Epoch 55/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# INFO:functions:Epoch 55/100: Train F1=0.9740, Test F1=0.7692, Train Recall=0.9754, Test Recall=1.0000
# Epoch 56/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.98it/s]
# Epoch 56/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 58.82it/s]
# INFO:functions:Epoch 56/100: Train F1=0.9668, Test F1=0.7692, Train Recall=0.9628, Test Recall=1.0000
# Epoch 57/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.77it/s]
# Epoch 57/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 57.14it/s]
# INFO:functions:Epoch 57/100: Train F1=0.9719, Test F1=0.7692, Train Recall=0.9708, Test Recall=1.0000
# Epoch 58/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.69it/s]
# Epoch 58/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 71.43it/s]
# INFO:functions:Epoch 58/100: Train F1=0.9730, Test F1=0.7692, Train Recall=0.9708, Test Recall=1.0000
# Epoch 59/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.85it/s]
# Epoch 59/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 68.97it/s]
# INFO:functions:Epoch 59/100: Train F1=0.9713, Test F1=0.7692, Train Recall=0.9751, Test Recall=1.0000
# Epoch 60/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.75it/s]
# Epoch 60/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 76.91it/s]
# INFO:functions:Epoch 60/100: Train F1=0.9733, Test F1=0.7692, Train Recall=0.9754, Test Recall=1.0000
# Epoch 61/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.78it/s]
# Epoch 61/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 68.96it/s]
# INFO:functions:Epoch 61/100: Train F1=0.9718, Test F1=0.7692, Train Recall=0.9714, Test Recall=1.0000
# Epoch 62/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.94it/s]
# Epoch 62/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 50.00it/s]
# INFO:functions:Epoch 62/100: Train F1=0.9717, Test F1=0.7692, Train Recall=0.9722, Test Recall=1.0000
# Epoch 63/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.73it/s]
# Epoch 63/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 68.96it/s]
# INFO:functions:Epoch 63/100: Train F1=0.9734, Test F1=0.7692, Train Recall=0.9745, Test Recall=1.0000
# Epoch 64/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.92it/s]
# Epoch 64/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 57.14it/s]
# INFO:functions:Epoch 64/100: Train F1=0.9737, Test F1=0.7692, Train Recall=0.9711, Test Recall=1.0000
# Epoch 65/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.69it/s]
# Epoch 65/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 66.67it/s]
# INFO:functions:Epoch 65/100: Train F1=0.9742, Test F1=0.7692, Train Recall=0.9794, Test Recall=1.0000
# Epoch 66/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.95it/s]
# Epoch 66/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 48.78it/s]
# INFO:functions:Epoch 66/100: Train F1=0.9711, Test F1=0.7692, Train Recall=0.9722, Test Recall=1.0000
# Epoch 67/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.77it/s]
# Epoch 67/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 66.63it/s]
# INFO:functions:Epoch 67/100: Train F1=0.9752, Test F1=0.7692, Train Recall=0.9754, Test Recall=1.0000
# Epoch 68/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.81it/s]
# Epoch 68/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 10.99it/s]
# INFO:functions:Epoch 68/100: Train F1=0.9763, Test F1=0.7692, Train Recall=0.9780, Test Recall=1.0000
# Epoch 69/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  3.00it/s]
# Epoch 69/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 60.61it/s]
# INFO:functions:Epoch 69/100: Train F1=0.9709, Test F1=0.7692, Train Recall=0.9694, Test Recall=1.0000
# Epoch 70/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.83it/s]
# Epoch 70/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# INFO:functions:Epoch 70/100: Train F1=0.9761, Test F1=0.7692, Train Recall=0.9777, Test Recall=1.0000
# Epoch 71/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.74it/s]
# Epoch 71/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 66.67it/s]
# INFO:functions:Epoch 71/100: Train F1=0.9743, Test F1=0.7692, Train Recall=0.9728, Test Recall=1.0000
# Epoch 72/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.83it/s]
# Epoch 72/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 67.78it/s]
# INFO:functions:Epoch 72/100: Train F1=0.9739, Test F1=0.7692, Train Recall=0.9737, Test Recall=1.0000
# Epoch 73/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.67it/s]
# Epoch 73/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# INFO:functions:Epoch 73/100: Train F1=0.9758, Test F1=0.7692, Train Recall=0.9797, Test Recall=1.0000
# Epoch 74/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.88it/s]
# Epoch 74/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 57.14it/s]
# INFO:functions:Epoch 74/100: Train F1=0.9755, Test F1=0.7692, Train Recall=0.9745, Test Recall=1.0000
# Epoch 75/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.60it/s]
# Epoch 75/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 64.51it/s]
# INFO:functions:Epoch 75/100: Train F1=0.9755, Test F1=0.7692, Train Recall=0.9757, Test Recall=1.0000
# Epoch 76/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.90it/s]
# Epoch 76/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 58.82it/s]
# INFO:functions:Epoch 76/100: Train F1=0.9756, Test F1=0.7692, Train Recall=0.9777, Test Recall=1.0000
# Epoch 77/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.86it/s]
# Epoch 77/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 76.92it/s]
# INFO:functions:Epoch 77/100: Train F1=0.9751, Test F1=0.7692, Train Recall=0.9768, Test Recall=1.0000
# Epoch 78/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.65it/s]
# Epoch 78/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.29it/s]
# INFO:functions:Epoch 78/100: Train F1=0.9765, Test F1=0.7692, Train Recall=0.9771, Test Recall=1.0000
# Epoch 79/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.95it/s]
# Epoch 79/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 57.14it/s]
# INFO:functions:Epoch 79/100: Train F1=0.9740, Test F1=0.7692, Train Recall=0.9751, Test Recall=1.0000
# Epoch 80/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.74it/s]
# Epoch 80/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 62.50it/s]
# INFO:functions:Epoch 80/100: Train F1=0.9751, Test F1=0.7692, Train Recall=0.9771, Test Recall=1.0000
# Epoch 81/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.82it/s]
# Epoch 81/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 68.97it/s]
# INFO:functions:Epoch 81/100: Train F1=0.9763, Test F1=0.7692, Train Recall=0.9745, Test Recall=1.0000
# Epoch 82/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.86it/s]
# Epoch 82/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 48.78it/s]
# INFO:functions:Epoch 82/100: Train F1=0.9749, Test F1=0.7692, Train Recall=0.9794, Test Recall=1.0000
# Epoch 83/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.73it/s]
# Epoch 83/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# INFO:functions:Epoch 83/100: Train F1=0.9754, Test F1=0.7692, Train Recall=0.9774, Test Recall=1.0000
# Epoch 84/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.66it/s]
# Epoch 84/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 68.97it/s]
# INFO:functions:Epoch 84/100: Train F1=0.9749, Test F1=0.7692, Train Recall=0.9742, Test Recall=1.0000
# Epoch 85/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.99it/s]
# Epoch 85/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 60.61it/s]
# INFO:functions:Epoch 85/100: Train F1=0.9758, Test F1=0.7692, Train Recall=0.9740, Test Recall=1.0000
# Epoch 86/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.81it/s]
# Epoch 86/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 62.50it/s]
# INFO:functions:Epoch 86/100: Train F1=0.9767, Test F1=0.7692, Train Recall=0.9785, Test Recall=1.0000
# Epoch 87/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.69it/s]
# Epoch 87/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 57.14it/s]
# INFO:functions:Epoch 87/100: Train F1=0.9758, Test F1=0.7692, Train Recall=0.9757, Test Recall=1.0000
# Epoch 88/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.66it/s]
# Epoch 88/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.08it/s]
# INFO:functions:Epoch 88/100: Train F1=0.9782, Test F1=0.7692, Train Recall=0.9817, Test Recall=1.0000
# Epoch 89/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.86it/s]
# Epoch 89/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 62.50it/s]
# INFO:functions:Epoch 89/100: Train F1=0.9760, Test F1=0.7692, Train Recall=0.9731, Test Recall=1.0000
# Epoch 90/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.82it/s]
# Epoch 90/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 62.50it/s]
# INFO:functions:Epoch 90/100: Train F1=0.9768, Test F1=0.7692, Train Recall=0.9757, Test Recall=1.0000
# Epoch 91/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.71it/s]
# Epoch 91/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 71.43it/s]
# INFO:functions:Epoch 91/100: Train F1=0.9765, Test F1=0.7692, Train Recall=0.9768, Test Recall=1.0000
# Epoch 92/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.84it/s]
# Epoch 92/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 50.00it/s]
# INFO:functions:Epoch 92/100: Train F1=0.9751, Test F1=0.7692, Train Recall=0.9762, Test Recall=1.0000
# Epoch 93/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.67it/s]
# Epoch 93/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 64.52it/s]
# INFO:functions:Epoch 93/100: Train F1=0.9757, Test F1=0.7692, Train Recall=0.9751, Test Recall=1.0000
# Epoch 94/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.64it/s]
# Epoch 94/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# INFO:functions:Epoch 94/100: Train F1=0.9741, Test F1=0.7692, Train Recall=0.9745, Test Recall=1.0000
# Epoch 95/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.93it/s]
# Epoch 95/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 57.14it/s]
# INFO:functions:Epoch 95/100: Train F1=0.9750, Test F1=0.7692, Train Recall=0.9777, Test Recall=1.0000
# Epoch 96/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.72it/s]
# Epoch 96/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 57.14it/s]
# INFO:functions:Epoch 96/100: Train F1=0.9751, Test F1=0.7692, Train Recall=0.9740, Test Recall=1.0000
# Epoch 97/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.68it/s]
# Epoch 97/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 68.97it/s]
# INFO:functions:Epoch 97/100: Train F1=0.9747, Test F1=0.7692, Train Recall=0.9748, Test Recall=1.0000
# Epoch 98/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.83it/s]
# Epoch 98/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 55.38it/s]
# INFO:functions:Epoch 98/100: Train F1=0.9745, Test F1=0.7692, Train Recall=0.9722, Test Recall=1.0000
# Epoch 99/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.80it/s]
# Epoch 99/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 58.83it/s]
# INFO:functions:Epoch 99/100: Train F1=0.9761, Test F1=0.7692, Train Recall=0.9757, Test Recall=1.0000
# Epoch 100/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.73it/s]
# Epoch 100/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 66.67it/s]
# INFO:functions:Epoch 100/100: Train F1=0.9759, Test F1=0.7692, Train Recall=0.9754, Test Recall=1.0000

# %%
import matplotlib.pyplot as plt


plot_results(
    train_losses, 
    test_losses, 
    train_f1_scores, 
    test_f1_scores, 
    train_recalls, 
    test_recalls,
    f"./{args.saved_dir}/linear_{args.version}.png"
)

# %%
import pandas as pd

metrics_data = {
    "Epoch": list(range(1, len(train_losses) + 1)),
    "Train Loss": train_losses,
    "Validation Loss": test_losses,
    "Train F1-Score": train_f1_scores,
    "Validation F1-Score": test_f1_scores,
    "Train Recall": train_recalls,
    "Validation Recall": test_recalls,
}

metrics_df = pd.DataFrame(metrics_data)

metrics_csv_path = f"./{args.saved_dir}/metrics_{args.version}.csv"
metrics_df.to_csv(metrics_csv_path, index=False)
