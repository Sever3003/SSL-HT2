# %%
from functions import *
from torchvision.transforms import InterpolationMode


# --- Configuration ---
class Config:
    saved_dir = 'saved'
    data_dir = "./pnev"
    backbone = "resnet18"
    version = 'pneumonia_task4_your'
    projection_dim = 128
    batch_size = 512
    simclr_epochs = 100
    learning_rate = 0.6
    weight_decay = 1e-6
    temperature = 0.5
    finetune_epochs = 100
    log_interval = 1

args = Config()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

from torchvision.models import resnet18
import torch
from torch.optim import SGD
from torch.optim.lr_scheduler import LambdaLR, CosineAnnealingLR
from torchvision.models import resnet18
from torchvision import transforms
from torch.utils.data import DataLoader


from torchvision import transforms
from torchvision.transforms import InterpolationMode
import torchvision.transforms.functional as F

train_transform = transforms.Compose([
    transforms.RandomApply([
        transforms.RandomRotation(
            degrees=(-10.0, 10.0),
            interpolation=InterpolationMode.NEAREST,
            expand=False,
            fill=0
        )
    ], p=0.5), 
    transforms.RandomResizedCrop(
        size=(224, 224),
        scale=(0.5, 1.0),
        ratio=(0.75, 1.3333333333333333),
        interpolation=InterpolationMode.BICUBIC,
        antialias=True
    ),
    transforms.RandomApply([
        transforms.ColorJitter(
            brightness=(0.8, 1.2),
            contrast=(0.8, 1.2)
        )
    ], p=0.5), 
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomApply([
        transforms.Lambda(lambda x: F.invert(x))
    ], p=0.5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5], inplace=False)
])

# %%
from medmnist import ChestMNIST, PneumoniaMNIST

# pneumoniamnist = GenericPairDataset(split='train', download=True, as_rgb=False, size=224)
pneumoniamnist = PneumoniaMNIST(split='train', download=True, as_rgb=False, size=224)
pneum_pair = GenericPairDataset(pneumoniamnist, transform=train_transform)
train_loader = DataLoader(pneum_pair, batch_size=args.batch_size, shuffle=True)


visualize(train_transform, pneumoniamnist, num_examples=5)
# Out:
# Using downloaded and verified file: C:\Users\sever\.medmnist\pneumoniamnist_224.npz

# %%
base_encoder = resnet18
model = SimCLR(base_encoder, projection_dim=args.projection_dim).to(device)

optimizer = SGD(model.parameters(), lr=args.learning_rate, momentum=0.9, weight_decay=args.weight_decay)
scheduler = LambdaLR(optimizer, lr_lambda=lambda step: get_lr(step, args.simclr_epochs * len(train_loader), args.learning_rate, 1e-4))

train_loss_simclr = train_simclr(model, train_loader, optimizer, scheduler, device, args.simclr_epochs)
torch.save(model.state_dict(), f"./{args.saved_dir}/{args.version}.pt")
# Out:
# c:\Users\sever\OneDrive\Рабочий стол\Homework2\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\sever\OneDrive\Рабочий стол\Homework2\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# 100%|██████████| 10/10 [00:17<00:00,  1.71s/it]
# INFO:functions:Epoch 1, Avg Loss: 6.7761
# 100%|██████████| 10/10 [00:17<00:00,  1.71s/it]
# INFO:functions:Epoch 2, Avg Loss: 6.5397
# 100%|██████████| 10/10 [00:16<00:00,  1.68s/it]
# INFO:functions:Epoch 3, Avg Loss: 6.3675
# 100%|██████████| 10/10 [00:16<00:00,  1.66s/it]
# INFO:functions:Epoch 4, Avg Loss: 6.2882
# 100%|██████████| 10/10 [00:16<00:00,  1.66s/it]
# INFO:functions:Epoch 5, Avg Loss: 6.1956
# 100%|██████████| 10/10 [00:16<00:00,  1.66s/it]
# INFO:functions:Epoch 6, Avg Loss: 6.1396
# 100%|██████████| 10/10 [00:16<00:00,  1.67s/it]
# INFO:functions:Epoch 7, Avg Loss: 6.1270
# 100%|██████████| 10/10 [00:16<00:00,  1.67s/it]
# INFO:functions:Epoch 8, Avg Loss: 6.0978
# 100%|██████████| 10/10 [00:16<00:00,  1.68s/it]
# INFO:functions:Epoch 9, Avg Loss: 6.1075
# 100%|██████████| 10/10 [00:16<00:00,  1.67s/it]
# INFO:functions:Epoch 10, Avg Loss: 6.0766
# 100%|██████████| 10/10 [00:16<00:00,  1.69s/it]
# INFO:functions:Epoch 11, Avg Loss: 6.0617
# 100%|██████████| 10/10 [00:16<00:00,  1.68s/it]
# INFO:functions:Epoch 12, Avg Loss: 6.0585
# 100%|██████████| 10/10 [00:16<00:00,  1.67s/it]
# INFO:functions:Epoch 13, Avg Loss: 6.0511
# 100%|██████████| 10/10 [00:16<00:00,  1.67s/it]
# INFO:functions:Epoch 14, Avg Loss: 6.0482
# 100%|██████████| 10/10 [00:16<00:00,  1.65s/it]
# INFO:functions:Epoch 15, Avg Loss: 6.0110
# 100%|██████████| 10/10 [00:16<00:00,  1.67s/it]
# INFO:functions:Epoch 16, Avg Loss: 6.0147
# 100%|██████████| 10/10 [00:16<00:00,  1.68s/it]
# INFO:functions:Epoch 17, Avg Loss: 5.9743
# 100%|██████████| 10/10 [00:16<00:00,  1.67s/it]
# INFO:functions:Epoch 18, Avg Loss: 5.9206
# 100%|██████████| 10/10 [00:16<00:00,  1.65s/it]
# INFO:functions:Epoch 19, Avg Loss: 5.8846
# 100%|██████████| 10/10 [00:16<00:00,  1.65s/it]
# INFO:functions:Epoch 20, Avg Loss: 5.8579
# 100%|██████████| 10/10 [00:16<00:00,  1.66s/it]
# INFO:functions:Epoch 21, Avg Loss: 5.8335
# 100%|██████████| 10/10 [00:16<00:00,  1.69s/it]
# INFO:functions:Epoch 22, Avg Loss: 5.8060
# 100%|██████████| 10/10 [00:16<00:00,  1.65s/it]
# INFO:functions:Epoch 23, Avg Loss: 5.7631
# 100%|██████████| 10/10 [00:12<00:00,  1.20s/it]
# INFO:functions:Epoch 24, Avg Loss: 5.7162
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 25, Avg Loss: 5.6747
# 100%|██████████| 10/10 [00:10<00:00,  1.05s/it]
# INFO:functions:Epoch 26, Avg Loss: 5.6573
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# INFO:functions:Epoch 27, Avg Loss: 5.6905
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# INFO:functions:Epoch 28, Avg Loss: 5.6340
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 29, Avg Loss: 5.6070
# 100%|██████████| 10/10 [00:10<00:00,  1.05s/it]
# INFO:functions:Epoch 30, Avg Loss: 5.5848
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 31, Avg Loss: 5.5799
# 100%|██████████| 10/10 [00:10<00:00,  1.05s/it]
# INFO:functions:Epoch 32, Avg Loss: 5.5555
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 33, Avg Loss: 5.5274
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 34, Avg Loss: 5.5175
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# INFO:functions:Epoch 35, Avg Loss: 5.4924
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 36, Avg Loss: 5.4765
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# INFO:functions:Epoch 37, Avg Loss: 5.4556
# 100%|██████████| 10/10 [00:10<00:00,  1.05s/it]
# INFO:functions:Epoch 38, Avg Loss: 5.4699
# 100%|██████████| 10/10 [00:10<00:00,  1.05s/it]
# INFO:functions:Epoch 39, Avg Loss: 5.4565
# 100%|██████████| 10/10 [00:10<00:00,  1.00s/it]
# INFO:functions:Epoch 40, Avg Loss: 5.4530
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 41, Avg Loss: 5.4391
# 100%|██████████| 10/10 [00:10<00:00,  1.01s/it]
# INFO:functions:Epoch 42, Avg Loss: 5.4363
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 43, Avg Loss: 5.4209
# 100%|██████████| 10/10 [00:09<00:00,  1.00it/s]
# INFO:functions:Epoch 44, Avg Loss: 5.4200
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 45, Avg Loss: 5.4229
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 46, Avg Loss: 5.4131
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 47, Avg Loss: 5.4066
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 48, Avg Loss: 5.3931
# 100%|██████████| 10/10 [00:10<00:00,  1.05s/it]
# INFO:functions:Epoch 49, Avg Loss: 5.3884
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 50, Avg Loss: 5.3820
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 51, Avg Loss: 5.3774
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# INFO:functions:Epoch 52, Avg Loss: 5.3678
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 53, Avg Loss: 5.3565
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 54, Avg Loss: 5.3623
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 55, Avg Loss: 5.3611
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 56, Avg Loss: 5.3653
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# INFO:functions:Epoch 57, Avg Loss: 5.3484
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 58, Avg Loss: 5.3421
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 59, Avg Loss: 5.3416
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 60, Avg Loss: 5.3494
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 61, Avg Loss: 5.3285
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 62, Avg Loss: 5.3226
# 100%|██████████| 10/10 [00:10<00:00,  1.01s/it]
# INFO:functions:Epoch 63, Avg Loss: 5.3248
# 100%|██████████| 10/10 [00:10<00:00,  1.01s/it]
# INFO:functions:Epoch 64, Avg Loss: 5.3282
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 65, Avg Loss: 5.3163
# 100%|██████████| 10/10 [00:10<00:00,  1.01s/it]
# INFO:functions:Epoch 66, Avg Loss: 5.3189
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 67, Avg Loss: 5.3185
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 68, Avg Loss: 5.3096
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 69, Avg Loss: 5.3077
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 70, Avg Loss: 5.3107
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# INFO:functions:Epoch 71, Avg Loss: 5.3048
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 72, Avg Loss: 5.2950
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 73, Avg Loss: 5.2935
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 74, Avg Loss: 5.2915
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 75, Avg Loss: 5.2943
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# INFO:functions:Epoch 76, Avg Loss: 5.2852
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# INFO:functions:Epoch 77, Avg Loss: 5.2839
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# INFO:functions:Epoch 78, Avg Loss: 5.2845
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 79, Avg Loss: 5.2809
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 80, Avg Loss: 5.2805
# 100%|██████████| 10/10 [00:10<00:00,  1.01s/it]
# INFO:functions:Epoch 81, Avg Loss: 5.2812
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 82, Avg Loss: 5.2799
# 100%|██████████| 10/10 [00:10<00:00,  1.01s/it]
# INFO:functions:Epoch 83, Avg Loss: 5.2755
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 84, Avg Loss: 5.2772
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 85, Avg Loss: 5.2810
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 86, Avg Loss: 5.2731
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# INFO:functions:Epoch 87, Avg Loss: 5.2760
# 100%|██████████| 10/10 [00:10<00:00,  1.05s/it]
# INFO:functions:Epoch 88, Avg Loss: 5.2717
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 89, Avg Loss: 5.2755
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 90, Avg Loss: 5.2695
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 91, Avg Loss: 5.2702
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 92, Avg Loss: 5.2683
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# INFO:functions:Epoch 93, Avg Loss: 5.2671
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# INFO:functions:Epoch 94, Avg Loss: 5.2673
# 100%|██████████| 10/10 [00:10<00:00,  1.06s/it]
# INFO:functions:Epoch 95, Avg Loss: 5.2691
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 96, Avg Loss: 5.2655
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# INFO:functions:Epoch 97, Avg Loss: 5.2661
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 98, Avg Loss: 5.2690
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 99, Avg Loss: 5.2665
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# INFO:functions:Epoch 100, Avg Loss: 5.2625

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(range(1, args.simclr_epochs + 1), train_loss_simclr, label="SimCLR Loss", marker='o')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("SimCLR Pretraining Loss")
plt.legend()
plt.grid(True)

plt.savefig(f'./{args.saved_dir}/pretrain_{args.version}.jpg') 

plt.show()

# %%
# Linear Probe
from medmnist import PneumoniaMNIST

test_transform = transforms.Compose([
    transforms.ToTensor(),
])

train_set_single = PneumoniaMNIST(split='train', download=True, as_rgb=False, transform=train_transform)
test_set_single = PneumoniaMNIST(split='test', download=True, as_rgb=False, transform=test_transform)
train_loader_single = DataLoader(train_set_single, batch_size=args.batch_size, shuffle=True)
test_loader_single = DataLoader(test_set_single, batch_size=args.batch_size, shuffle=False)
# Out:
# Using downloaded and verified file: C:\Users\sever\.medmnist\pneumoniamnist.npz
# Using downloaded and verified file: C:\Users\sever\.medmnist\pneumoniamnist.npz

# %%
for param in model.enc.parameters():
    param.requires_grad = False
    
lin_model = LinModel(model.enc, model.feature_dim, n_classes=2).to(device)

optimizer = torch.optim.SGD(
    lin_model.parameters(),
    lr=0.2,
    momentum=0.9,
    weight_decay=0.,
    nesterov=True
)

scheduler = LambdaLR(
    optimizer,
    lr_lambda=lambda step: get_lr(
        step,
        args.finetune_epochs * len(train_loader_single),
        args.learning_rate,
        1e-4
    )
)

# --- Обучение ---
results = train_linear_probe(
    lin_model,
    train_loader_single,
    test_loader_single,
    optimizer,
    scheduler,
    device,
    args.finetune_epochs,
    [0.5, 0.5]
)


train_losses, test_losses, train_f1_scores, test_f1_scores, train_recalls, test_recalls, train_precisions, test_precisions = results
# Out:
# Epoch 1/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.27it/s]
# Epoch 1/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 43.48it/s]
# INFO:functions:Epoch 1/100: Train F1=0.9030, Test F1=0.7692, Train Recall=0.9061, Test Recall=1.0000
# Epoch 2/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.26it/s]
# Epoch 2/100 - Testing: 100%|██████████| 2/2 [00:00<00:00,  8.10it/s]
# INFO:functions:Epoch 2/100: Train F1=0.9353, Test F1=0.7692, Train Recall=0.9396, Test Recall=1.0000
# Epoch 3/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.28it/s]
# Epoch 3/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 67.56it/s]
# INFO:functions:Epoch 3/100: Train F1=0.9020, Test F1=0.7692, Train Recall=0.9038, Test Recall=1.0000
# Epoch 4/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.26it/s]
# Epoch 4/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 71.43it/s]
# c:\Users\sever\OneDrive\Рабочий стол\Homework2\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# INFO:functions:Epoch 4/100: Train F1=0.9308, Test F1=0.0000, Train Recall=0.9284, Test Recall=0.0000
# Epoch 5/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.20it/s]
# Epoch 5/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 66.67it/s]
# INFO:functions:Epoch 5/100: Train F1=0.9234, Test F1=0.7692, Train Recall=0.9093, Test Recall=1.0000
# Epoch 6/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.21it/s]
# Epoch 6/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# c:\Users\sever\OneDrive\Рабочий стол\Homework2\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# INFO:functions:Epoch 6/100: Train F1=0.9188, Test F1=0.0000, Train Recall=0.9136, Test Recall=0.0000
# Epoch 7/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.27it/s]
# Epoch 7/100 - Testing: 100%|██████████| 2/2 [00:00<00:00,  5.97it/s]
# INFO:functions:Epoch 7/100: Train F1=0.9318, Test F1=0.7692, Train Recall=0.9193, Test Recall=1.0000
# Epoch 8/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.33it/s]
# Epoch 8/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 58.82it/s]
# INFO:functions:Epoch 8/100: Train F1=0.9134, Test F1=0.7692, Train Recall=0.9207, Test Recall=1.0000
# Epoch 9/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.13it/s]
# Epoch 9/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.08it/s]
# INFO:functions:Epoch 9/100: Train F1=0.9347, Test F1=0.7231, Train Recall=0.9471, Test Recall=0.8538
# Epoch 10/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.22it/s]
# Epoch 10/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 10.20it/s]
# INFO:functions:Epoch 10/100: Train F1=0.9263, Test F1=0.7692, Train Recall=0.9224, Test Recall=1.0000
# Epoch 11/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.28it/s]
# Epoch 11/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 64.52it/s]
# INFO:functions:Epoch 11/100: Train F1=0.9423, Test F1=0.7692, Train Recall=0.9485, Test Recall=1.0000
# Epoch 12/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.13it/s]
# Epoch 12/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 71.43it/s]
# INFO:functions:Epoch 12/100: Train F1=0.9123, Test F1=0.7692, Train Recall=0.9153, Test Recall=1.0000
# Epoch 13/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.35it/s]
# Epoch 13/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 58.82it/s]
# INFO:functions:Epoch 13/100: Train F1=0.9497, Test F1=0.7548, Train Recall=0.9508, Test Recall=0.9513
# Epoch 14/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.27it/s]
# Epoch 14/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 61.37it/s]
# INFO:functions:Epoch 14/100: Train F1=0.9234, Test F1=0.7700, Train Recall=0.9242, Test Recall=1.0000
# Epoch 15/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.26it/s]
# Epoch 15/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 64.52it/s]
# INFO:functions:Epoch 15/100: Train F1=0.9135, Test F1=0.7692, Train Recall=0.9110, Test Recall=1.0000
# Epoch 16/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.13it/s]
# Epoch 16/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 71.43it/s]
# c:\Users\sever\OneDrive\Рабочий стол\Homework2\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# INFO:functions:Epoch 16/100: Train F1=0.9481, Test F1=0.0000, Train Recall=0.9522, Test Recall=0.0000
# Epoch 17/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.35it/s]
# Epoch 17/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 55.56it/s]
# INFO:functions:Epoch 17/100: Train F1=0.9142, Test F1=0.7692, Train Recall=0.9053, Test Recall=1.0000
# Epoch 18/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.10it/s]
# Epoch 18/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 68.97it/s]
# INFO:functions:Epoch 18/100: Train F1=0.9537, Test F1=0.7700, Train Recall=0.9571, Test Recall=1.0000
# Epoch 19/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.18it/s]
# Epoch 19/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 76.92it/s]
# INFO:functions:Epoch 19/100: Train F1=0.9067, Test F1=0.7692, Train Recall=0.9084, Test Recall=1.0000
# Epoch 20/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.15it/s]
# Epoch 20/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.08it/s]
# INFO:functions:Epoch 20/100: Train F1=0.9477, Test F1=0.4154, Train Recall=0.9519, Test Recall=0.3179
# Epoch 21/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.35it/s]
# Epoch 21/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 57.06it/s]
# INFO:functions:Epoch 21/100: Train F1=0.9268, Test F1=0.6945, Train Recall=0.9256, Test Recall=0.8103
# Epoch 22/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.16it/s]
# Epoch 22/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 71.43it/s]
# INFO:functions:Epoch 22/100: Train F1=0.9367, Test F1=0.7692, Train Recall=0.9276, Test Recall=1.0000
# Epoch 23/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.26it/s]
# Epoch 23/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 62.50it/s]
# INFO:functions:Epoch 23/100: Train F1=0.9337, Test F1=0.7692, Train Recall=0.9425, Test Recall=1.0000
# Epoch 24/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.12it/s]
# Epoch 24/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 71.43it/s]
# INFO:functions:Epoch 24/100: Train F1=0.9477, Test F1=0.7700, Train Recall=0.9525, Test Recall=1.0000
# Epoch 25/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.32it/s]
# Epoch 25/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 55.56it/s]
# INFO:functions:Epoch 25/100: Train F1=0.9435, Test F1=0.2195, Train Recall=0.9388, Test Recall=0.1359
# Epoch 26/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.19it/s]
# Epoch 26/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 68.97it/s]
# INFO:functions:Epoch 26/100: Train F1=0.9425, Test F1=0.7700, Train Recall=0.9385, Test Recall=1.0000
# Epoch 27/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.21it/s]
# Epoch 27/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.29it/s]
# INFO:functions:Epoch 27/100: Train F1=0.9413, Test F1=0.0341, Train Recall=0.9439, Test Recall=0.0179
# Epoch 28/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.31it/s]
# Epoch 28/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 64.52it/s]
# INFO:functions:Epoch 28/100: Train F1=0.9129, Test F1=0.7692, Train Recall=0.9090, Test Recall=1.0000
# Epoch 29/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.23it/s]
# Epoch 29/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 50.00it/s]
# INFO:functions:Epoch 29/100: Train F1=0.9522, Test F1=0.7558, Train Recall=0.9485, Test Recall=0.9641
# Epoch 30/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.21it/s]
# Epoch 30/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 64.52it/s]
# INFO:functions:Epoch 30/100: Train F1=0.9397, Test F1=0.7700, Train Recall=0.9410, Test Recall=1.0000
# Epoch 31/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.27it/s]
# Epoch 31/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 71.43it/s]
# INFO:functions:Epoch 31/100: Train F1=0.9478, Test F1=0.7659, Train Recall=0.9505, Test Recall=0.9897
# Epoch 32/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.22it/s]
# Epoch 32/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 76.92it/s]
# INFO:functions:Epoch 32/100: Train F1=0.9427, Test F1=0.7700, Train Recall=0.9442, Test Recall=1.0000
# Epoch 33/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.19it/s]
# Epoch 33/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# INFO:functions:Epoch 33/100: Train F1=0.9406, Test F1=0.7692, Train Recall=0.9430, Test Recall=1.0000
# Epoch 34/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.35it/s]
# Epoch 34/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 55.56it/s]
# INFO:functions:Epoch 34/100: Train F1=0.9565, Test F1=0.7700, Train Recall=0.9588, Test Recall=1.0000
# Epoch 35/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.06it/s]
# Epoch 35/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 67.78it/s]
# INFO:functions:Epoch 35/100: Train F1=0.9114, Test F1=0.7692, Train Recall=0.9159, Test Recall=1.0000
# Epoch 36/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.16it/s]
# Epoch 36/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 71.42it/s]
# INFO:functions:Epoch 36/100: Train F1=0.9524, Test F1=0.7354, Train Recall=0.9505, Test Recall=0.9051
# Epoch 37/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.29it/s]
# Epoch 37/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 60.61it/s]
# INFO:functions:Epoch 37/100: Train F1=0.9420, Test F1=0.7583, Train Recall=0.9433, Test Recall=0.9692
# Epoch 38/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.18it/s]
# Epoch 38/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 69.17it/s]
# INFO:functions:Epoch 38/100: Train F1=0.9430, Test F1=0.7595, Train Recall=0.9450, Test Recall=0.9718
# Epoch 39/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.18it/s]
# Epoch 39/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 68.97it/s]
# INFO:functions:Epoch 39/100: Train F1=0.9524, Test F1=0.7692, Train Recall=0.9485, Test Recall=1.0000
# Epoch 40/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.35it/s]
# Epoch 40/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 57.14it/s]
# INFO:functions:Epoch 40/100: Train F1=0.9301, Test F1=0.7692, Train Recall=0.9350, Test Recall=1.0000
# Epoch 41/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.31it/s]
# Epoch 41/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 64.52it/s]
# INFO:functions:Epoch 41/100: Train F1=0.9504, Test F1=0.7700, Train Recall=0.9508, Test Recall=1.0000
# Epoch 42/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.16it/s]
# Epoch 42/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 76.92it/s]
# INFO:functions:Epoch 42/100: Train F1=0.9427, Test F1=0.7688, Train Recall=0.9482, Test Recall=0.9974
# Epoch 43/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.37it/s]
# Epoch 43/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 57.14it/s]
# INFO:functions:Epoch 43/100: Train F1=0.9308, Test F1=0.7692, Train Recall=0.9322, Test Recall=1.0000
# Epoch 44/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.16it/s]
# Epoch 44/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 68.97it/s]
# INFO:functions:Epoch 44/100: Train F1=0.9377, Test F1=0.7700, Train Recall=0.9516, Test Recall=1.0000
# Epoch 45/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.30it/s]
# Epoch 45/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 62.50it/s]
# INFO:functions:Epoch 45/100: Train F1=0.9514, Test F1=0.5400, Train Recall=0.9502, Test Recall=0.5103
# Epoch 46/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.29it/s]
# Epoch 46/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 62.50it/s]
# INFO:functions:Epoch 46/100: Train F1=0.9353, Test F1=0.7700, Train Recall=0.9310, Test Recall=1.0000
# Epoch 47/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.13it/s]
# Epoch 47/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# INFO:functions:Epoch 47/100: Train F1=0.9513, Test F1=0.7700, Train Recall=0.9525, Test Recall=1.0000
# Epoch 48/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.28it/s]
# Epoch 48/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 68.97it/s]
# INFO:functions:Epoch 48/100: Train F1=0.9489, Test F1=0.7700, Train Recall=0.9493, Test Recall=1.0000
# Epoch 49/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.24it/s]
# Epoch 49/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 64.52it/s]
# INFO:functions:Epoch 49/100: Train F1=0.9530, Test F1=0.7007, Train Recall=0.9525, Test Recall=0.8282
# Epoch 50/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.24it/s]
# Epoch 50/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 62.50it/s]
# INFO:functions:Epoch 50/100: Train F1=0.9403, Test F1=0.7692, Train Recall=0.9325, Test Recall=1.0000
# Epoch 51/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.22it/s]
# Epoch 51/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 76.93it/s]
# INFO:functions:Epoch 51/100: Train F1=0.9411, Test F1=0.7700, Train Recall=0.9450, Test Recall=1.0000
# Epoch 52/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.35it/s]
# Epoch 52/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 36.36it/s]
# INFO:functions:Epoch 52/100: Train F1=0.9526, Test F1=0.7692, Train Recall=0.9542, Test Recall=1.0000
# Epoch 53/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.22it/s]
# Epoch 53/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 64.52it/s]
# INFO:functions:Epoch 53/100: Train F1=0.9449, Test F1=0.7700, Train Recall=0.9496, Test Recall=1.0000
# Epoch 54/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.18it/s]
# Epoch 54/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 73.94it/s]
# INFO:functions:Epoch 54/100: Train F1=0.9570, Test F1=0.7683, Train Recall=0.9528, Test Recall=0.9949
# Epoch 55/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.34it/s]
# Epoch 55/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 50.09it/s]
# INFO:functions:Epoch 55/100: Train F1=0.9492, Test F1=0.7700, Train Recall=0.9488, Test Recall=1.0000
# Epoch 56/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.27it/s]
# Epoch 56/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 45.45it/s]
# INFO:functions:Epoch 56/100: Train F1=0.9518, Test F1=0.7642, Train Recall=0.9502, Test Recall=0.9846
# Epoch 57/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.21it/s]
# Epoch 57/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 66.67it/s]
# INFO:functions:Epoch 57/100: Train F1=0.9479, Test F1=0.7700, Train Recall=0.9442, Test Recall=1.0000
# Epoch 58/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.12it/s]
# Epoch 58/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# INFO:functions:Epoch 58/100: Train F1=0.9528, Test F1=0.7570, Train Recall=0.9528, Test Recall=0.9667
# Epoch 59/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.16it/s]
# Epoch 59/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 71.43it/s]
# INFO:functions:Epoch 59/100: Train F1=0.9498, Test F1=0.7700, Train Recall=0.9419, Test Recall=1.0000
# Epoch 60/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.28it/s]
# Epoch 60/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 58.82it/s]
# INFO:functions:Epoch 60/100: Train F1=0.9583, Test F1=0.7700, Train Recall=0.9596, Test Recall=1.0000
# Epoch 61/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.13it/s]
# Epoch 61/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 71.43it/s]
# INFO:functions:Epoch 61/100: Train F1=0.9578, Test F1=0.7700, Train Recall=0.9588, Test Recall=1.0000
# Epoch 62/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.22it/s]
# Epoch 62/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 66.67it/s]
# INFO:functions:Epoch 62/100: Train F1=0.9585, Test F1=0.7700, Train Recall=0.9585, Test Recall=1.0000
# Epoch 63/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.29it/s]
# Epoch 63/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 60.03it/s]
# INFO:functions:Epoch 63/100: Train F1=0.9594, Test F1=0.7688, Train Recall=0.9614, Test Recall=0.9974
# Epoch 64/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.19it/s]
# Epoch 64/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 59.02it/s]
# INFO:functions:Epoch 64/100: Train F1=0.9571, Test F1=0.7700, Train Recall=0.9551, Test Recall=1.0000
# Epoch 65/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.22it/s]
# Epoch 65/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 62.50it/s]
# INFO:functions:Epoch 65/100: Train F1=0.9572, Test F1=0.7666, Train Recall=0.9565, Test Recall=0.9897
# Epoch 66/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.22it/s]
# Epoch 66/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 60.73it/s]
# INFO:functions:Epoch 66/100: Train F1=0.9566, Test F1=0.7700, Train Recall=0.9499, Test Recall=1.0000
# Epoch 67/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.14it/s]
# Epoch 67/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 76.92it/s]
# INFO:functions:Epoch 67/100: Train F1=0.9609, Test F1=0.7700, Train Recall=0.9645, Test Recall=1.0000
# Epoch 68/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.17it/s]
# Epoch 68/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 74.07it/s]
# INFO:functions:Epoch 68/100: Train F1=0.9563, Test F1=0.7700, Train Recall=0.9551, Test Recall=1.0000
# Epoch 69/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.33it/s]
# Epoch 69/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 64.52it/s]
# INFO:functions:Epoch 69/100: Train F1=0.9542, Test F1=0.7683, Train Recall=0.9531, Test Recall=0.9949
# Epoch 70/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.13it/s]
# Epoch 70/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 58.82it/s]
# INFO:functions:Epoch 70/100: Train F1=0.9565, Test F1=0.7700, Train Recall=0.9513, Test Recall=1.0000
# Epoch 71/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.15it/s]
# Epoch 71/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 71.43it/s]
# INFO:functions:Epoch 71/100: Train F1=0.9584, Test F1=0.7700, Train Recall=0.9556, Test Recall=1.0000
# Epoch 72/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.21it/s]
# Epoch 72/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 80.24it/s]
# INFO:functions:Epoch 72/100: Train F1=0.9562, Test F1=0.7700, Train Recall=0.9562, Test Recall=1.0000
# Epoch 73/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.36it/s]
# Epoch 73/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 52.63it/s]
# INFO:functions:Epoch 73/100: Train F1=0.9580, Test F1=0.7700, Train Recall=0.9594, Test Recall=1.0000
# Epoch 74/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.19it/s]
# Epoch 74/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 44.44it/s]
# INFO:functions:Epoch 74/100: Train F1=0.9617, Test F1=0.7700, Train Recall=0.9588, Test Recall=1.0000
# Epoch 75/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.16it/s]
# Epoch 75/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 76.92it/s]
# INFO:functions:Epoch 75/100: Train F1=0.9571, Test F1=0.7700, Train Recall=0.9551, Test Recall=1.0000
# Epoch 76/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.14it/s]
# Epoch 76/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 76.92it/s]
# INFO:functions:Epoch 76/100: Train F1=0.9577, Test F1=0.7700, Train Recall=0.9562, Test Recall=1.0000
# Epoch 77/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.30it/s]
# Epoch 77/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 58.82it/s]
# INFO:functions:Epoch 77/100: Train F1=0.9592, Test F1=0.7700, Train Recall=0.9588, Test Recall=1.0000
# Epoch 78/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.08it/s]
# Epoch 78/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 66.67it/s]
# INFO:functions:Epoch 78/100: Train F1=0.9574, Test F1=0.7700, Train Recall=0.9528, Test Recall=1.0000
# Epoch 79/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.30it/s]
# Epoch 79/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 76.92it/s]
# INFO:functions:Epoch 79/100: Train F1=0.9584, Test F1=0.7700, Train Recall=0.9571, Test Recall=1.0000
# Epoch 80/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.11it/s]
# Epoch 80/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 80.00it/s]
# INFO:functions:Epoch 80/100: Train F1=0.9607, Test F1=0.7700, Train Recall=0.9596, Test Recall=1.0000
# Epoch 81/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.39it/s]
# Epoch 81/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 55.56it/s]
# INFO:functions:Epoch 81/100: Train F1=0.9617, Test F1=0.7700, Train Recall=0.9585, Test Recall=1.0000
# Epoch 82/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.60it/s]
# Epoch 82/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 66.67it/s]
# INFO:functions:Epoch 82/100: Train F1=0.9599, Test F1=0.7700, Train Recall=0.9599, Test Recall=1.0000
# Epoch 83/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.55it/s]
# Epoch 83/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 54.05it/s]
# INFO:functions:Epoch 83/100: Train F1=0.9618, Test F1=0.7700, Train Recall=0.9614, Test Recall=1.0000
# Epoch 84/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.59it/s]
# Epoch 84/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 57.15it/s]
# INFO:functions:Epoch 84/100: Train F1=0.9616, Test F1=0.7700, Train Recall=0.9611, Test Recall=1.0000
# Epoch 85/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.58it/s]
# Epoch 85/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 66.82it/s]
# INFO:functions:Epoch 85/100: Train F1=0.9625, Test F1=0.7700, Train Recall=0.9614, Test Recall=1.0000
# Epoch 86/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.45it/s]
# Epoch 86/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 66.67it/s]
# INFO:functions:Epoch 86/100: Train F1=0.9592, Test F1=0.7700, Train Recall=0.9559, Test Recall=1.0000
# Epoch 87/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.47it/s]
# Epoch 87/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 68.96it/s]
# INFO:functions:Epoch 87/100: Train F1=0.9585, Test F1=0.7700, Train Recall=0.9545, Test Recall=1.0000
# Epoch 88/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.44it/s]
# Epoch 88/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 60.61it/s]
# INFO:functions:Epoch 88/100: Train F1=0.9592, Test F1=0.7700, Train Recall=0.9579, Test Recall=1.0000
# Epoch 89/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.48it/s]
# Epoch 89/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 80.00it/s]
# INFO:functions:Epoch 89/100: Train F1=0.9608, Test F1=0.7700, Train Recall=0.9568, Test Recall=1.0000
# Epoch 90/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.53it/s]
# Epoch 90/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 51.28it/s]
# INFO:functions:Epoch 90/100: Train F1=0.9571, Test F1=0.7700, Train Recall=0.9554, Test Recall=1.0000
# Epoch 91/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.39it/s]
# Epoch 91/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 66.82it/s]
# INFO:functions:Epoch 91/100: Train F1=0.9613, Test F1=0.7700, Train Recall=0.9599, Test Recall=1.0000
# Epoch 92/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.47it/s]
# Epoch 92/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 68.97it/s]
# INFO:functions:Epoch 92/100: Train F1=0.9607, Test F1=0.7700, Train Recall=0.9616, Test Recall=1.0000
# Epoch 93/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.48it/s]
# Epoch 93/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 62.63it/s]
# INFO:functions:Epoch 93/100: Train F1=0.9605, Test F1=0.7700, Train Recall=0.9579, Test Recall=1.0000
# Epoch 94/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.54it/s]
# Epoch 94/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 76.92it/s]
# INFO:functions:Epoch 94/100: Train F1=0.9625, Test F1=0.7700, Train Recall=0.9594, Test Recall=1.0000
# Epoch 95/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.55it/s]
# Epoch 95/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 46.51it/s]
# INFO:functions:Epoch 95/100: Train F1=0.9596, Test F1=0.7700, Train Recall=0.9562, Test Recall=1.0000
# Epoch 96/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.68it/s]
# Epoch 96/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 58.91it/s]
# INFO:functions:Epoch 96/100: Train F1=0.9584, Test F1=0.7700, Train Recall=0.9551, Test Recall=1.0000
# Epoch 97/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.47it/s]
# Epoch 97/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 80.00it/s]
# INFO:functions:Epoch 97/100: Train F1=0.9605, Test F1=0.7700, Train Recall=0.9574, Test Recall=1.0000
# Epoch 98/100 - Training: 100%|██████████| 10/10 [00:03<00:00,  2.64it/s]
# Epoch 98/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 52.63it/s]
# INFO:functions:Epoch 98/100: Train F1=0.9640, Test F1=0.7700, Train Recall=0.9588, Test Recall=1.0000
# Epoch 99/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.37it/s]
# Epoch 99/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 66.67it/s]
# INFO:functions:Epoch 99/100: Train F1=0.9578, Test F1=0.7700, Train Recall=0.9582, Test Recall=1.0000
# Epoch 100/100 - Training: 100%|██████████| 10/10 [00:04<00:00,  2.46it/s]
# Epoch 100/100 - Testing: 100%|██████████| 2/2 [00:00<00:00, 64.52it/s]
# INFO:functions:Epoch 100/100: Train F1=0.9589, Test F1=0.7700, Train Recall=0.9576, Test Recall=1.0000

# %%
import matplotlib.pyplot as plt

plot_results(
    train_losses, 
    test_losses, 
    train_f1_scores, 
    test_f1_scores, 
    train_recalls, 
    test_recalls,
    f"./{args.saved_dir}/linear_{args.version}.png"
)

# %%
import pandas as pd

metrics_data = {
    "Epoch": list(range(1, len(train_losses) + 1)),
    "Train Loss": train_losses,
    "Validation Loss": test_losses,
    "Train F1-Score": train_f1_scores,
    "Validation F1-Score": test_f1_scores,
    "Train Recall": train_recalls,
    "Validation Recall": test_recalls,
}

metrics_df = pd.DataFrame(metrics_data)

metrics_csv_path = f"./{args.saved_dir}/metrics_{args.version}.csv"
metrics_df.to_csv(metrics_csv_path, index=False)
